# %% [markdown]
# <h1 align="center">Perceptron-Trick</h1>

# %%
# making random classification data 

from sklearn.datasets import make_classification

X,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,
                          n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
# looking at our classification graph

plt.Figure(figsize=(25,10))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.show()

# %%
# checking shapes
X.shape , y.shape

# %%
# define the perceptron trick function 

def perceptron(X,y):
  X = np.insert(X,0,1,axis=1) # axis 1 because 1 -> coulumns , 0-> rows
  weights = np.ones(X.shape[1])
  lr = 0.1
  epochs = 1000

  for i in range(epochs):
    j = np.random.randint(0,100) # this represent the random student we are seleceting 
    y_hat = step(np.dot(X[j],weights))
    weights = weights +  lr*(y[j]-y_hat) * X[j]
  
  return weights[0],weights[1:]

# %%
# initializing step 

def step(z):
  return 1 if z>0 else 0

# %%
# computing intercept and cofficients 

intercept_,coef_ = perceptron(X,y)

# %%
print(intercept_)
print(coef_)

# %%
# computing m and b for line generation

m  = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
# plotting the graph

plt.Figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1], c=y , cmap='winter' , s =100)
plt.ylim(-3,2)
plt.show()

# %%
# # now we will draw the animations as well 

# def perceptron(X,y):

#   m = []
#   b = []

#   X = np.insert(X,0,1,axis=1) # axis 1 because 1 -> coulumns , 0-> rows
#   weights = np.ones(X.shape[1])
#   lr = 0.1
#   epochs = 1000

#   for i in range(epochs):
#     j = np.random.randint(0,100) # this represent the random student we are seleceting 
#     y_hat = step(np.dot(X[j],weights))
#     weights = weights +  lr*(y[j]-y_hat) * X[j]

#     m.append(-(weights[1]/weights[2]))
#     b.append(-(weights[0]/weights[2]))
  
#   return m , b

# %%
# m,b = perceptron(X,y)
