# %% [markdown]
# <h1 align="center">Lecture - 4 </h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# for plotting the region we use mlxtend lib
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv("/Users/piyush/Repositories/Deep-Learning/Datasets/placement.csv")

# %%
print(df.shape)
df.head()
# Out:
# (200, 3)
#    cgpa  resume_score  placed
# 0  6.75          1.23       0
# 1  3.48          3.01       0
# 2  7.63          7.09       1
# 3  9.03          1.78       1
# 4  1.27          2.97       0

# %%
# Plotting the data on scatterplot 

sns.scatterplot(
    x=df['cgpa'],
    y=df['resume_score'],
    hue=df['placed']
)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
# Splitting the data set 
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
print(X.shape)
print(y.shape)
# Out:
# (200, 2)
# (200,)

# %%
# Importing scikit_learn lib to compute perceptron
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[20.16,  2.71]])

# %%
p.intercept_
# Out:
# array([-147.])

# %%
# plotting the reigons 
# clf -> classifier 
plot_decision_regions(X.values,y.values, clf=p , legend = 2)
# Out:
# /Users/piyush/Repositories/Deep-Learning/env/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
